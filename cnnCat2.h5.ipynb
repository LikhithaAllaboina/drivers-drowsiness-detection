# %%
# CNN
import os
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from keras.utils.np_utils import to_categorical
import random, shutil
from keras.models import Sequential
from keras.layers import (
    Dropout,
    Conv2D,
    Flatten,
    Dense,
    MaxPooling2D,
    BatchNormalization,
)
from keras.models import load_model


def generator(
    dir,
    gen=image.ImageDataGenerator(rescale=1.0 / 255),
    shuffle=True,
    batch_size=1,
    target_size=(24, 24),
    class_mode="categorical",
):

    return gen.flow_from_directory(
        dir,
        batch_size=batch_size,
        shuffle=shuffle,
        color_mode="grayscale",
        class_mode=class_mode,
        target_size=target_size,
    )


BS = 32
TS = (24, 24)
train_batch = generator("F:\downloads\dataset_new\dl_train", shuffle=True, batch_size=BS, target_size=TS)
valid_batch = generator("F:\downloads\dataset_new\dl_test", shuffle=True, batch_size=BS, target_size=TS)
SPE = len(train_batch.classes) // BS
VS = len(valid_batch.classes) // BS
print(SPE, VS)

img, labels = next(train_batch)
print(img.shape)

cnn_model = Sequential(
    [
        Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(24, 24, 1)),
        MaxPooling2D(pool_size=(1, 1)),
        Conv2D(32, (3, 3), activation="relu"),
        MaxPooling2D(pool_size=(1, 1)),
        Conv2D(64, (3, 3), activation="relu"),
        MaxPooling2D(pool_size=(1, 1)),
        Dropout(0.25),
        Flatten(),
        Dense(128, activation="relu"),
        Dropout(0.5),
        Dense(4, activation="softmax"),
    ]
)
#compilation of sequential model
cnn_model.compile(
    optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
)
cnn_model.fit(
    train_batch,
    validation_data=valid_batch,
    epochs=50,
    steps_per_epoch=SPE,
    validation_steps=VS,
)
cnn_model.save("cnnCat2.h5",overwrite=True)
# Out:
# Found 2467 images belonging to 4 classes.
# Found 433 images belonging to 4 classes.
# 77 13
# (32, 24, 24, 1)
# Epoch 1/50
# 77/77 [==============================] - 15s 185ms/step - loss: 0.7416 - accuracy: 0.6468 - val_loss: 0.4928 - val_accuracy: 0.7740
# Epoch 2/50
# 77/77 [==============================] - 12s 151ms/step - loss: 0.4502 - accuracy: 0.7713 - val_loss: 0.3899 - val_accuracy: 0.8149
# Epoch 3/50
# 77/77 [==============================] - 11s 148ms/step - loss: 0.3896 - accuracy: 0.7975 - val_loss: 0.3820 - val_accuracy: 0.8101
# Epoch 4/50
# 77/77 [==============================] - 12s 150ms/step - loss: 0.3585 - accuracy: 0.8111 - val_loss: 0.3467 - val_accuracy: 0.8245
# Epoch 5/50
# 77/77 [==============================] - 12s 154ms/step - loss: 0.3646 - accuracy: 0.8156 - val_loss: 0.3457 - val_accuracy: 0.8317
# Epoch 6/50
# 77/77 [==============================] - 12s 152ms/step - loss: 0.3119 - accuracy: 0.8386 - val_loss: 0.3085 - val_accuracy: 0.8389
# ...
